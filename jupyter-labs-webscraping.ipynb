# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Space X  Falcon 9 First Stage Landing Prediction**

# %% [markdown]
# ## Web scraping Falcon 9 and Falcon Heavy Launches Records from Wikipedia

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# In this lab, you will be performing web scraping to collect Falcon 9 historical launch records from a Wikipedia page titled `List of Falcon 9 and Falcon Heavy launches`
#
# https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_1_L2/images/Falcon9_rocket_family.svg)

# %% [markdown]
# Falcon 9 first stage will land successfully

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/landing_1.gif)

# %% [markdown]
# Several examples of an unsuccessful landing are shown here:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/crash.gif)

# %% [markdown]
# More specifically, the launch records are stored in a HTML table shown below:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_1_L2/images/falcon9-launches-wiki.png)

# %% [markdown]
#   ## Objectives
# Web scrap Falcon 9 launch records with `BeautifulSoup`:
# - Extract a Falcon 9 launch records HTML table from Wikipedia
# - Parse the table and convert it into a Pandas data frame

# %% [markdown]
# First let's import required packages for this lab

# %%
# !pip3 install beautifulsoup4
# !pip3 install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: beautifulsoup4 in /home/emintiras/.local/lib/python3.10/site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /home/emintiras/.local/lib/python3.10/site-packages (from beautifulsoup4) (2.4.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /home/emintiras/.local/lib/python3.10/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/emintiras/.local/lib/python3.10/site-packages (from requests) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/emintiras/.local/lib/python3.10/site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests) (2020.6.20)

# %%
import sys

import requests
from bs4 import BeautifulSoup
import re
import unicodedata
import pandas as pd

# %% [markdown]
# and we will provide some helper functions for you to process web scraped HTML table

# %%
def date_time(table_cells):
    """
    This function returns the data and time from the HTML  table cell
    Input: the  element of a table data cell extracts extra row
    """
    return [data_time.strip() for data_time in list(table_cells.strings)][0:2]

def booster_version(table_cells):
    """
    This function returns the booster version from the HTML  table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=''.join([booster_version for i,booster_version in enumerate( table_cells.strings) if i%2==0][0:-1])
    return out

def landing_status(table_cells):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=[i for i in table_cells.strings][0]
    return out


def get_mass(table_cells):
    mass=unicodedata.normalize("NFKD", table_cells.text).strip()
    if mass:
        mass.find("kg")
        new_mass=mass[0:mass.find("kg")+2]
    else:
        new_mass=0
    return new_mass


def extract_column_from_header(row):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    if (row.br):
        row.br.extract()
    if row.a:
        row.a.extract()
    if row.sup:
        row.sup.extract()
        
    colunm_name = ' '.join(row.contents)
    
    # Filter the digit and empty names
    if not(colunm_name.strip().isdigit()):
        colunm_name = colunm_name.strip()
        return colunm_name

# %% [markdown]
# To keep the lab tasks consistent, you will be asked to scrape the data from a snapshot of the  `List of Falcon 9 and Falcon Heavy launches` Wikipage updated on
# `9th June 2021`

# %%
static_url = "https://en.wikipedia.org/w/index.php?title=List_of_Falcon_9_and_Falcon_Heavy_launches&oldid=1027686922"

# %% [markdown]
# Next, request the HTML page from the above URL and get a `response` object

# %% [markdown]
# ### TASK 1: Request the Falcon9 Launch Wiki page from its URL

# %% [markdown]
# First, let's perform an HTTP GET method to request the Falcon9 Launch HTML page, as an HTTP response.

# %%
# use requests.get() method with the provided static_url
# assign the response to a object
url = "https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches"

# Perform an HTTP GET request to fetch the HTML content
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# Create a `BeautifulSoup` object from the HTML `response`

# %%
# Use BeautifulSoup() to create a BeautifulSoup object from a response text content
soup = BeautifulSoup(response.text, 'html.parser')
    
    # Print the title of the page to confirm we have the correct content
print(soup.title.string)
# Out:
# List of Falcon 9 and Falcon Heavy launches - Wikipedia

# %% [markdown]
# Print the page title to verify if the `BeautifulSoup` object was created properly

# %%
# Use soup.title attribute
#print(soup.title.string)

# %% [markdown]
# ### TASK 2: Extract all column/variable names from the HTML table header

# %% [markdown]
# Next, we want to collect all relevant column names from the HTML table header

# %% [markdown]
# Let's try to find all tables on the wiki page first. If you need to refresh your memory about `BeautifulSoup`, please check the external reference link towards the end of this lab

# %%
# Use the find_all function in the BeautifulSoup object, with element type `table`
# Assign the result to a list called `html_tables`
soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all tables on the wiki page
html_tables = soup.find_all('table')

# %% [markdown]
# Starting from the third table is our target table contains the actual launch records.

# %%
# Let's print the third table and check its content
first_launch_table = html_tables[2]
print(first_launch_table)
# Out:
# <table class="wikitable" style="width:100%; font-size:1.00em; line-height:1.5em;">
# <tbody><tr class="is-sticky">
# <th scope="col" style="width: 10%;">Date and time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>booster</a><sup class="reference" id="cite_ref-booster_26-2"><a href="#cite_note-booster-26">[c]</a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_27-2"><a href="#cite_note-Dragon-27">[d]</a></sup>
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th></tr>
# <tr>
# <td rowspan="2">9 August 2024 12:13<sup class="reference" id="cite_ref-nextSFupcoming_393-1"><a href="#cite_note-nextSFupcoming-393">[385]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">Cape Canaveral</a>, <a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC‑40</a>
# </td>
# <td><a href="/wiki/Starlink" title="Starlink">Starlink Group 8-3</a> (~20 satellites)
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td></tr>
# <tr>
# <td colspan="5">An East Coast v2 mini Starlink launch to their Generation 2 network.
# </td></tr>
# <tr>
# <td rowspan="2">10 August 2024 11:21<sup class="reference" id="cite_ref-nextSFupcoming_393-2"><a href="#cite_note-nextSFupcoming-393">[385]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">Kennedy</a>, <a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC‑39A</a>
# </td>
# <td><a href="/wiki/Starlink" title="Starlink">Starlink Group 10-7</a> (~23 satellites)
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td></tr>
# <tr>
# <td colspan="5">An East Coast v2 mini Starlink launch to their Generation 2 network.
# </td></tr>
# <tr>
# <td rowspan="2">12 August 2024 02:00<sup class="reference" id="cite_ref-394"><a href="#cite_note-394">[386]</a></sup><sup class="reference" id="cite_ref-395"><a href="#cite_note-395">[387]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a><br/><a href="/wiki/List_of_Falcon_9_first-stage_boosters#B1061" title="List of Falcon 9 first-stage boosters">B1061.22</a><span class="nowrap"> </span>♺
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">Vandenberg</a>, <a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC‑4E</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Arctic_Satellite_Broadband_Mission" title="Arctic Satellite Broadband Mission">ASBM 1</a> (<a class="mw-redirect" href="/wiki/Global_Xpress" title="Global Xpress">GX</a> 10A), <a class="mw-redirect" href="/wiki/Arctic_Satellite_Broadband_Mission" title="Arctic Satellite Broadband Mission">ASBM 2</a> (<a class="mw-redirect" href="/wiki/Global_Xpress" title="Global Xpress">GX</a> 10B)<sup class="reference" id="cite_ref-396"><a href="#cite_note-396">[388]</a></sup>
# </td>
# <td><a href="/wiki/Highly_elliptical_orbit" title="Highly elliptical orbit">HEO</a>
# </td>
# <td><a href="/wiki/Norwegian_Space_Agency" title="Norwegian Space Agency">Space Norway</a> / <a href="/wiki/Inmarsat" title="Inmarsat">Inmarsat</a>
# </td></tr>
# <tr>
# <td colspan="5"><a href="/wiki/Norwegian_Space_Agency" title="Norwegian Space Agency">Space Norway</a> will launch 2 satellites of the <a class="mw-redirect" href="/wiki/Arctic_Satellite_Broadband_Mission" title="Arctic Satellite Broadband Mission">Arctic Satellite Broadband Mission</a> (ASBM) system into highly elliptical orbits (apogee: 43,509 km (27,035 mi), perigee: 8,089 km (5,026 mi), 63.4° inclination)<sup class="reference" id="cite_ref-397"><a href="#cite_note-397">[389]</a></sup> to provide communication coverage to high latitudes not served by geosynchronous satellites.<sup class="reference" id="cite_ref-398"><a href="#cite_note-398">[390]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">14 August 2024<sup class="reference" id="cite_ref-nextSFupcoming_393-3"><a href="#cite_note-nextSFupcoming-393">[385]</a></sup><sup class="reference" id="cite_ref-shephard14224_399-0"><a href="#cite_note-shephard14224-399">[391]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a> ♺<sup class="reference" id="cite_ref-worldviewlegion_341-2"><a href="#cite_note-worldviewlegion-341">[333]</a></sup><sup class="reference" id="cite_ref-WorldView-Legion_1,_...,_6_400-0"><a href="#cite_note-WorldView-Legion_1,_...,_6-400">[392]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">Cape Canaveral</a>, <a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC‑40</a>
# </td>
# <td><a href="/wiki/DigitalGlobe#WorldView_Legion" title="DigitalGlobe">WorldView Legion 3 &amp; 4</a> Mission 2 (2 satellites)<sup class="reference" id="cite_ref-spacenews.com_401-0"><a href="#cite_note-spacenews.com-401">[393]</a></sup><sup class="reference" id="cite_ref-SN240423_402-0"><a href="#cite_note-SN240423-402">[394]</a></sup><sup class="reference" id="cite_ref-worldviewLegion10QSept22_403-0"><a href="#cite_note-worldviewLegion10QSept22-403">[395]</a></sup>
# </td>
# <td><a href="/wiki/Sun-synchronous_orbit" title="Sun-synchronous orbit">SSO</a>
# </td>
# <td><a href="/wiki/Maxar_Technologies" title="Maxar Technologies">Maxar Technologies</a>
# </td></tr>
# <tr>
# <td colspan="5"><a href="/wiki/Maxar_Technologies" title="Maxar Technologies">Maxar Technologies</a> built satellites.
# </td></tr>
# <tr>
# <td rowspan="2">15 August 2024<sup class="reference" id="cite_ref-nextSFupcoming_393-4"><a href="#cite_note-nextSFupcoming-393">[385]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">Vandenberg</a>, <a class="mw-redirect" href="/wiki/SLC-4E" title="SLC-4E">SLC-4E</a>
# </td>
# <td><a href="/wiki/List_of_spaceflight_launches_in_July%E2%80%93December_2024#SpXTransporter11" title="List of spaceflight launches in July–December 2024">Transporter-11</a> (smallsat rideshare)<sup class="reference" id="cite_ref-spacex-smallsat_307-2"><a href="#cite_note-spacex-smallsat-307">[299]</a></sup>
# </td>
# <td><a href="/wiki/Sun-synchronous_orbit" title="Sun-synchronous orbit">SSO</a>
# </td>
# <td>Various
# </td></tr>
# <tr>
# <td colspan="5">Dedicated SmallSat Rideshare mission to sun-synchronous orbit.
# </td></tr>
# <tr>
# <td rowspan="2">August 2024<sup class="reference" id="cite_ref-nextSFupcoming_393-5"><a href="#cite_note-nextSFupcoming-393">[385]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">Cape Canaveral</a>, <a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC‑40</a>
# </td>
# <td><a href="/wiki/Starlink" title="Starlink">Starlink Group 10-5</a> (~23 satellites)
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td></tr>
# <tr>
# <td colspan="5">An East Coast v2 mini Starlink launch to their Generation 2 network.
# </td></tr>
# <tr>
# <td rowspan="2">August 2024<sup class="reference" id="cite_ref-nextSFupcoming_393-6"><a href="#cite_note-nextSFupcoming-393">[385]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a><br/><a href="/wiki/List_of_Falcon_9_first-stage_boosters#B1083" title="List of Falcon 9 first-stage boosters">B1083.4</a><span class="nowrap"> </span>♺
# </td>
# <td><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">Kennedy</a>, <a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC‑39A</a>
# </td>
# <td><a href="/wiki/Polaris_Dawn" title="Polaris Dawn">Polaris Dawn</a> (<a href="/wiki/Crew_Dragon_Resilience" title="Crew Dragon Resilience">Crew Dragon C207.3 <i>Resilience</i></a> ♺)<sup class="reference" id="cite_ref-404"><a href="#cite_note-404">[396]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Polaris_Program" title="Polaris Program">Polaris Program</a>
# </td></tr>
# <tr>
# <td colspan="5">First of two <a href="/wiki/SpaceX_Dragon_2" title="SpaceX Dragon 2">Crew Dragon</a> missions for the Polaris Program. Crew will consist of <a href="/wiki/Jared_Isaacman" title="Jared Isaacman">Jared Isaacman</a>, <a href="/wiki/Scott_Poteet" title="Scott Poteet">Scott Poteet</a>, <a href="/wiki/Sarah_Gillis" title="Sarah Gillis">Sarah Gillis</a> and <a href="/wiki/Anna_Menon" title="Anna Menon">Anna Menon</a> and will spend up to five days in orbit. Flying higher than any crewed Earth orbiting spacecraft has ever flown, Polaris Dawn will conduct research with the aim of better understanding the effects of spaceflight and space radiation on human health. At approximately 700 kilometers above the Earth, the crew will attempt the first-ever commercial extravehicular activity (EVA) with SpaceX-designed EVA spacesuits, derived from the existing intravehicular (IVA) suit.
# </td></tr>
# <tr>
# <td rowspan="2">August 2024<sup class="reference" id="cite_ref-405"><a href="#cite_note-405">[397]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td>TBA (FL)
# </td>
# <td><a href="/wiki/GSAT-20" title="GSAT-20">GSAT-20</a><sup class="reference" id="cite_ref-NSIL_406-0"><a href="#cite_note-NSIL-406">[398]</a></sup> (CMS-03)
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/New_Space_India_Limited" title="New Space India Limited">New Space India Limited</a><sup class="reference" id="cite_ref-NSIL_406-1"><a href="#cite_note-NSIL-406">[398]</a></sup><br/><a href="/wiki/Dish_TV" title="Dish TV">Dish TV</a><sup class="reference" id="cite_ref-407"><a href="#cite_note-407">[399]</a></sup>
# </td></tr>
# <tr>
# <td colspan="5">Indian telecommunications satellite for <a href="/wiki/Dish_TV" title="Dish TV">Dish TV</a>. Originally planned to launch on <a href="/wiki/ISRO" title="ISRO">ISRO</a>'s <a href="/wiki/LVM3" title="LVM3">LVM3</a>,<sup class="reference" id="cite_ref-annualreport2018_408-0"><a href="#cite_note-annualreport2018-408">[400]</a></sup> but later shifted to <a href="/wiki/Falcon_9" title="Falcon 9">Falcon 9</a> due to mass and scheduling issues.<sup class="reference" id="cite_ref-sn-20240102_409-0"><a href="#cite_note-sn-20240102-409">[401]</a></sup> It will be the first ISRO-made satellite to move from <a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">geostationary transfer orbit</a> to <a href="/wiki/Geostationary_orbit" title="Geostationary orbit">geostationary orbit</a> using electric propulsion.<sup class="reference" id="cite_ref-thewire_410-0"><a href="#cite_note-thewire-410">[402]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">13 September 2024 <sup class="reference" id="cite_ref-Galileo_411-0"><a href="#cite_note-Galileo-411">[403]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a><br/><a href="/wiki/List_of_Falcon_9_first-stage_boosters#B1062" title="List of Falcon 9 first-stage boosters">B1062.23</a><span class="nowrap"> </span>♺
# </td>
# <td>TBA (FL)
# </td>
# <td>2 × <a href="/wiki/Galileo_(satellite_navigation)" title="Galileo (satellite navigation)">Galileo</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Medium_Earth_Orbit" title="Medium Earth Orbit">MEO</a>
# </td>
# <td><a href="/wiki/European_Space_Agency" title="European Space Agency">ESA</a>
# </td></tr>
# <tr>
# <td colspan="5">Second launch of Galileo satellites.
# </td></tr>
# <tr>
# <td rowspan="2">24 September 2024<sup class="reference" id="cite_ref-:8_412-0"><a href="#cite_note-:8-412">[404]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a> <br/><a href="/wiki/List_of_Falcon_9_first-stage_boosters#B1085" title="List of Falcon 9 first-stage boosters">B1085.1</a>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">Cape Canaveral</a>, <a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC‑40</a>
# </td>
# <td><a href="/wiki/SpaceX_Crew-9" title="SpaceX Crew-9">Crew-9</a> (<a href="/wiki/Crew_Dragon_Freedom" title="Crew Dragon Freedom">Crew Dragon C212.4 <i>Freedom</i></a> ♺)<sup class="reference" id="cite_ref-NASACREW7-9_189-2"><a href="#cite_note-NASACREW7-9-189">[181]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a class="mw-redirect" href="/wiki/ISS" title="ISS">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a class="mw-redirect" href="/wiki/ISS_Crew_Transportation_Services" title="ISS Crew Transportation Services">CTS</a>)<sup class="reference" id="cite_ref-CCD6_85-5"><a href="#cite_note-CCD6-85">[77]</a></sup>
# </td></tr>
# <tr>
# <td colspan="5">After first six <a class="mw-redirect" href="/wiki/Crew_Dragon" title="Crew Dragon">Crew Dragon</a> launches of NASA <a class="mw-redirect" href="/wiki/Commercial_Crew_Development" title="Commercial Crew Development">USCV</a> award, a further three missions for SpaceX were announced on 3 December 2021. These launches carry up to four astronauts and 100 kg (220 lb) of cargo to the ISS as well as feature a lifeboat function to evacuate astronauts from ISS in case of an emergency.<sup class="reference" id="cite_ref-CCD6_85-6"><a href="#cite_note-CCD6-85">[77]</a></sup> First crewed mission to launch from <a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">Cape Canaveral Space Launch Complex 40</a>.<sup class="reference" id="cite_ref-:8_412-1"><a href="#cite_note-:8-412">[404]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">September 2024 <sup class="reference" id="cite_ref-DoD28222_413-0"><a href="#cite_note-DoD28222-413">[405]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">Vandenberg</a>, <a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC‑4E</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency#Launches" title="Space Development Agency">SDA Tranche 1 Tracking layer T1TL-B</a><sup class="reference" id="cite_ref-SSCA12_414-0"><a href="#cite_note-SSCA12-414">[406]</a></sup>
# </td>
# <td><a href="/wiki/Polar_orbit" title="Polar orbit">Polar</a> <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency" title="Space Development Agency">SDA</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2022.
# </td></tr>
# <tr>
# <td rowspan="2">Q3 2024 <sup class="reference" id="cite_ref-415"><a href="#cite_note-415">[407]</a></sup><sup class="reference" id="cite_ref-416"><a href="#cite_note-416">[408]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td>TBA (FL)
# </td>
# <td><a href="/wiki/Astranis" title="Astranis">MicroGEO</a> (4 satellites)<sup class="reference" id="cite_ref-astranis-microgeo-f9_417-0"><a href="#cite_note-astranis-microgeo-f9-417">[409]</a></sup>
# </td>
# <td><a href="/wiki/Geostationary_orbit" title="Geostationary orbit">GEO</a>
# </td>
# <td><a href="/wiki/Astranis" title="Astranis">Astranis</a>
# </td></tr>
# <tr>
# <td colspan="5">Dedicated Falcon 9 launch to put four Astranis MicroGEO communications satellites into service in 2023.<sup class="reference" id="cite_ref-astranis-microgeo-f9_417-1"><a href="#cite_note-astranis-microgeo-f9-417">[409]</a></sup> The MicroGEOs will be launched to a custom geostationary orbit, with the four satellites individually conducting on-orbit maneuvers to inject themselves into their orbital slots. However, it is unclear whether this will be a direct to <a href="/wiki/Geostationary_orbit" title="Geostationary orbit">geostationary orbit</a> insertion, or an optimized <a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">geostationary transfer orbit</a>. The four spacecraft will be mounted to a standard adapter ring, known as an <a href="/wiki/EELV_Secondary_Payload_Adapter" title="EELV Secondary Payload Adapter">ESPA-Grande</a>, for ease of deployment.
# </td></tr>
# <tr>
# <td rowspan="2">Q3 2024 <sup class="reference" id="cite_ref-nextSFupcoming_393-7"><a href="#cite_note-nextSFupcoming-393">[385]</a></sup><sup class="reference" id="cite_ref-Rainbow_418-0"><a href="#cite_note-Rainbow-418">[410]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td>TBA (FL)
# </td>
# <td>BlueBird Block 1 (5 satellites)<sup class="reference" id="cite_ref-AST_SpaceMobile_delays_commercial_s_419-0"><a href="#cite_note-AST_SpaceMobile_delays_commercial_s-419">[411]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/AST_SpaceMobile" title="AST SpaceMobile">AST SpaceMobile</a>
# </td></tr>
# <tr>
# <td colspan="5">Cellphone-compatible broadband constellation. Each satellite is to be a similar size and weight to its 1,500-kilogram BlueWalker 3 prototype and have a 64 square meter phased array antenna.
# </td></tr>
# <tr>
# <td rowspan="2">7 October 2024<sup class="reference" id="cite_ref-sn-20221020_157-1"><a href="#cite_note-sn-20221020-157">[149]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td>TBA (FL)
# </td>
# <td><a href="/wiki/Hera_(space_mission)" title="Hera (space mission)">Hera</a> with Juventas and Milani
# </td>
# <td><a href="/wiki/Heliocentric_orbit" title="Heliocentric orbit">Heliocentric</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/ESA" title="ESA">ESA</a>
# </td></tr>
# <tr>
# <td colspan="5">Hera is a space mission in development at the <a href="/wiki/European_Space_Agency" title="European Space Agency">European Space Agency</a> in its Space Safety program. Its primary objective is to study the <a href="/wiki/65803_Didymos" title="65803 Didymos">Didymos binary asteroid system</a> that was impacted by <a href="/wiki/Double_Asteroid_Redirection_Test" title="Double Asteroid Redirection Test">DART</a> and contribute to validation of the <a href="/wiki/Kinetic_energy" title="Kinetic energy">kinetic</a> impact method to deviate a <a href="/wiki/Near-Earth_object" title="Near-Earth object">near-Earth asteroid</a> in a colliding trajectory with Earth. It will measure the size and the morphology of the crater created by and momentum transferred by an artificial projectile impacting an asteroid, which will allow measuring the efficiency of the deflection produced by the impact. It will also carry two <a href="/wiki/Small_satellite" title="Small satellite">nano-satellite</a> CubeSats, called <i>Milani</i> and <i>Juventas</i>.
# </td></tr>
# <tr>
# <td rowspan="4">10 October 2024 <sup class="reference" id="cite_ref-420"><a href="#cite_note-420">[412]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_Heavy" title="Falcon Heavy">Falcon Heavy B5</a><br/><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">B1090</a><span class="nowrap"> </span>(core)
# </td>
# <td rowspan="3"><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">Kennedy</a>, <a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC‑39A</a>
# </td>
# <td rowspan="3"><a href="/wiki/Europa_Clipper" title="Europa Clipper">Europa Clipper</a>
# </td>
# <td rowspan="3"><a href="/wiki/Heliocentric_orbit" title="Heliocentric orbit">Heliocentric</a>
# </td>
# <td rowspan="3"><a href="/wiki/NASA" title="NASA">NASA</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/List_of_Falcon_9_first-stage_boosters#B1064" title="List of Falcon 9 first-stage boosters">B1064.6</a><span class="nowrap"> </span>(side)<span class="nowrap"> </span>♺<sup class="reference" id="cite_ref-arstechpsyche20230829_421-0"><a href="#cite_note-arstechpsyche20230829-421">[413]</a></sup>
# </td></tr>
# <tr>
# <td><a href="/wiki/List_of_Falcon_9_first-stage_boosters#B1065" title="List of Falcon 9 first-stage boosters">B1065.6</a><span class="nowrap"> </span>(side)<span class="nowrap"> </span>♺<sup class="reference" id="cite_ref-arstechpsyche20230829_421-1"><a href="#cite_note-arstechpsyche20230829-421">[413]</a></sup>
# </td></tr>
# <tr>
# <td colspan="5"><a href="/wiki/Europa_Clipper" title="Europa Clipper">Europa Clipper</a> will conduct a detailed survey of <a href="/wiki/Europa_(moon)" title="Europa (moon)">Europa</a> and use a sophisticated suite of science instruments to investigate whether the icy moon has conditions suitable for life. Key mission objectives are to produce high-resolution images of Europa's surface, determine its composition, look for signs of recent or ongoing geological activity, measure the thickness of the moon's icy shell, search for subsurface lakes, and determine the depth and salinity of Europa's ocean.<sup class="reference" id="cite_ref-NASA_EC_L_422-0"><a href="#cite_note-NASA_EC_L-422">[414]</a></sup> The mission will fly past Mars and Earth before arriving at Jupiter in April 2030.<sup class="reference" id="cite_ref-423"><a href="#cite_note-423">[415]</a></sup><sup class="reference" id="cite_ref-424"><a href="#cite_note-424">[416]</a></sup> The side boosters and the center core will all be expended.
# </td></tr>
# <tr>
# <td rowspan="2">Mid-October 2024<sup class="reference" id="cite_ref-:8_412-2"><a href="#cite_note-:8-412">[404]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td>TBA (FL)
# </td>
# <td><a href="/wiki/SpaceX_CRS-31" title="SpaceX CRS-31">SpaceX CRS-31</a><sup class="reference" id="cite_ref-March2022CRS2_319-1"><a href="#cite_note-March2022CRS2-319">[311]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a class="mw-redirect" href="/wiki/ISS" title="ISS">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td></tr>
# <tr>
# <td colspan="5">Six additional <a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS-2</a> missions for Dragon 2 were announced in March 2022, resupplying the ISS until 2026.
# </td></tr>
# <tr>
# <td rowspan="2">October 2024 <sup class="reference" id="cite_ref-425"><a href="#cite_note-425">[417]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td>TBA (FL)
# </td>
# <td><a class="mw-redirect" href="/wiki/Blue_Ghost" title="Blue Ghost">Blue Ghost</a> M1<sup class="reference" id="cite_ref-426"><a href="#cite_note-426">[418]</a></sup><sup class="reference" id="cite_ref-427"><a href="#cite_note-427">[419]</a></sup>
# </td>
# <td><a href="/wiki/Trans-lunar_injection" title="Trans-lunar injection">TLI</a>
# </td>
# <td><a href="/wiki/Firefly_Aerospace" title="Firefly Aerospace">Firefly Aerospace</a><br/>NASA (<a href="/wiki/Commercial_Lunar_Payload_Services" title="Commercial Lunar Payload Services">CLPS</a>)
# </td></tr>
# <tr>
# <td colspan="5"><a href="/wiki/Firefly_Aerospace" title="Firefly Aerospace">Firefly Aerospace</a> has selected <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>'s Falcon 9 rocket to deliver the Blue Ghost lunar lander to the lunar surface.<sup class="reference" id="cite_ref-428"><a href="#cite_note-428">[420]</a></sup> Blue Ghost will carry 10 payloads for NASA's <a href="/wiki/Commercial_Lunar_Payload_Services" title="Commercial Lunar Payload Services">Commercial Lunar Payload Services</a> task order 19D mission along with other separately contracted payloads.<sup class="reference" id="cite_ref-429"><a href="#cite_note-429">[421]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">October 2024 <sup class="reference" id="cite_ref-spacex-smallsat_307-3"><a href="#cite_note-spacex-smallsat-307">[299]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">Vandenberg</a>, <a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC‑4E</a>
# </td>
# <td><a href="/wiki/List_of_spaceflight_launches_in_July%E2%80%93December_2024#SpXTransporter12" title="List of spaceflight launches in July–December 2024">Transporter-12</a> (smallsat rideshare)
# </td>
# <td><a href="/wiki/Sun-synchronous_orbit" title="Sun-synchronous orbit">SSO</a>
# </td>
# <td>Various
# </td></tr>
# <tr>
# <td colspan="5">Dedicated SmallSat Rideshare mission to sun-synchronous orbit.
# </td></tr>
# <tr>
# <td rowspan="2">October 2024<sup class="reference" id="cite_ref-DoD28222_413-1"><a href="#cite_note-DoD28222-413">[405]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">Vandenberg</a>, <a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC‑4E</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency#Launches" title="Space Development Agency">SDA Tranche 1 Tracking layer T1TL-C</a><sup class="reference" id="cite_ref-SSCA12_414-1"><a href="#cite_note-SSCA12-414">[406]</a></sup>
# </td>
# <td><a href="/wiki/Polar_orbit" title="Polar orbit">Polar</a> <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency" title="Space Development Agency">SDA</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2022.
# </td></tr>
# <tr>
# <td rowspan="2">October 2024<sup class="reference" id="cite_ref-430"><a href="#cite_note-430">[422]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">Kennedy</a>, <a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC‑39A</a>
# </td>
# <td><a href="/wiki/Axiom_Mission_4" title="Axiom Mission 4">Ax-4</a><sup class="reference" id="cite_ref-axiom_132-2"><a href="#cite_note-axiom-132">[124]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a class="mw-redirect" href="/wiki/ISS" title="ISS">ISS</a>)
# </td>
# <td><a href="/wiki/Axiom_Space" title="Axiom Space">Axiom Space</a>
# </td></tr>
# <tr>
# <td colspan="5">Contract for 3 additional missions was signed in June 2021.
# </td></tr>
# <tr>
# <td rowspan="2">November 2024<sup class="reference" id="cite_ref-atalayar-20240422_431-0"><a href="#cite_note-atalayar-20240422-431">[423]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td>TBA (FL)
# </td>
# <td><a href="/wiki/Spainsat_NG" title="Spainsat NG">Spainsat-NG I</a><sup class="reference" id="cite_ref-hisdesat-20221107_432-0"><a href="#cite_note-hisdesat-20221107-432">[424]</a></sup>
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>
# </td>
# <td><a href="/wiki/Hisdesat" title="Hisdesat">Hisdesat</a>
# </td></tr>
# <tr>
# <td colspan="5">Communications satellite built on the <a href="/wiki/Eurostar_(satellite_bus)" title="Eurostar (satellite bus)">Eurostar-Neo</a> platform, to be utilized by the Spanish government and its allies.<sup class="reference" id="cite_ref-:7_433-0"><a href="#cite_note-:7-433">[425]</a></sup> First of two launches for the Spainsat-NG program.
# </td></tr>
# <tr>
# <td rowspan="3">November 2024
# </td>
# <td rowspan="2"><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td rowspan="2">TBA (FL)
# </td>
# <td><a href="/wiki/List_of_spaceflight_launches_in_July%E2%80%93December_2024#SpXBandwagon2" title="List of spaceflight launches in July–December 2024">Bandwagon-2</a> (smallsat rideshare)<sup class="reference" id="cite_ref-spacex-smallsat_307-4"><a href="#cite_note-spacex-smallsat-307">[299]</a></sup><sup class="reference" id="cite_ref-BandW_329-1"><a href="#cite_note-BandW-329">[321]</a></sup>
# </td>
# <td rowspan="2"><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td>Various
# </td></tr>
# <tr>
# <td>425 Project Flight 3
# </td>
# <td><a href="/wiki/Republic_of_Korea_Armed_Forces" title="Republic of Korea Armed Forces">Republic of Korea Armed Forces</a>
# </td></tr>
# <tr>
# <td colspan="5">Dedicated SmallSat Rideshare mission to 45 degree inclination 550–600 km altitude. 425 Project Flight 3 is a military satellite of South Korea with a mass of ~800 kg.<sup class="reference" id="cite_ref-yonhap8124_434-0"><a href="#cite_note-yonhap8124-434">[426]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">November 2024<sup class="reference" id="cite_ref-DoD28222_413-2"><a href="#cite_note-DoD28222-413">[405]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">Vandenberg</a>, <a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC‑4E</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency#Launches" title="Space Development Agency">SDA Tranche 1 Tracking layer T1TL-D</a><sup class="reference" id="cite_ref-SSCA12_414-2"><a href="#cite_note-SSCA12-414">[406]</a></sup>
# </td>
# <td><a href="/wiki/Polar_orbit" title="Polar orbit">Polar</a> <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency" title="Space Development Agency">SDA</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2022.
# </td></tr>
# <tr>
# <td rowspan="2">December 2024<sup class="reference" id="cite_ref-DoD28222_413-3"><a href="#cite_note-DoD28222-413">[405]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">Vandenberg</a>, <a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC‑4E</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency#Launches" title="Space Development Agency">SDA Tranche 1 Tracking layer T1TL-E</a><sup class="reference" id="cite_ref-SSCA12_414-3"><a href="#cite_note-SSCA12-414">[406]</a></sup>
# </td>
# <td><a href="/wiki/Polar_orbit" title="Polar orbit">Polar</a> <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency" title="Space Development Agency">SDA</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2022.
# </td></tr>
# <tr>
# <td rowspan="2">Q4 2024<sup class="reference" id="cite_ref-DoD28222_413-4"><a href="#cite_note-DoD28222-413">[405]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td><a href="/wiki/Vandenberg_Space_Force_Base" title="Vandenberg Space Force Base">Vandenberg</a>, <a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC‑4E</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency#Launches" title="Space Development Agency">SDA Tranche 1 Transport layer T1TR-C</a><sup class="reference" id="cite_ref-SSCA12_414-4"><a href="#cite_note-SSCA12-414">[406]</a></sup>
# </td>
# <td><a href="/wiki/Polar_orbit" title="Polar orbit">Polar</a> <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Space_Development_Agency" title="Space Development Agency">SDA</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2022.
# </td></tr>
# <tr>
# <td rowspan="2">Q4 2024<sup class="reference" id="cite_ref-sn-20240213_435-0"><a href="#cite_note-sn-20240213-435">[427]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td><a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">Kennedy</a>, <a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC‑39A</a><sup class="reference" id="cite_ref-436"><a href="#cite_note-436">[428]</a></sup>
# </td>
# <td><a href="/wiki/IM-2" title="IM-2">IM-2</a> <i><a class="mw-redirect" href="/wiki/Nova-C" title="Nova-C">Nova-C</a></i> lunar lander<br/><a href="/wiki/SHERPA_(space_tug)" title="SHERPA (space tug)">Sherpa-ES</a>
# </td>
# <td><a href="/wiki/Trans-lunar_injection" title="Trans-lunar injection">TLI</a>
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Lunar_Payload_Services" title="Commercial Lunar Payload Services">CLPS</a>)<br/><a href="/wiki/Intuitive_Machines" title="Intuitive Machines">Intuitive Machines</a><br/><a href="/wiki/Spaceflight,_Inc." title="Spaceflight, Inc.">Spaceflight, Inc.</a>
# </td></tr>
# <tr>
# <td colspan="5">Intuitive Machines is sending its second lander aboard a SpaceX Falcon 9, with a projected launch time frame in late 2024. In February 2024, Intuitive Machines has completed its first lander mission via SpaceX, which is also hosting payloads for other private companies seeking to make lunar landfall under NASA's Commercial Lunar Payload Services program. NASA's <a href="/wiki/PRIME-1" title="PRIME-1">PRIME-1</a> is expected to be included.<sup class="reference" id="cite_ref-437"><a href="#cite_note-437">[429]</a></sup> The Sherpa-ES <i>Go Beyond</i> orbital transfer vehicle will deploy rideshare payloads to trans-lunar orbit, low-lunar orbit and beyond to GEO.<sup class="reference" id="cite_ref-438"><a href="#cite_note-438">[430]</a></sup><sup class="reference" id="cite_ref-439"><a href="#cite_note-439">[431]</a></sup><sup class="reference" id="cite_ref-440"><a href="#cite_note-440">[432]</a></sup> NASA's <a href="/wiki/Lunar_Trailblazer" title="Lunar Trailblazer">Lunar Trailblazer</a> mission will fly as a secondary payload on this mission.<sup class="reference" id="cite_ref-441"><a href="#cite_note-441">[433]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">Q4 2024<sup class="reference" id="cite_ref-442"><a href="#cite_note-442">[434]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td>TBA (FL)
# </td>
# <td><a href="/wiki/Koreasat" title="Koreasat">Koreasat</a> 6A<sup class="reference" id="cite_ref-443"><a href="#cite_note-443">[435]</a></sup>
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>
# </td>
# <td><a href="/wiki/KT_Corporation" title="KT Corporation">KT Sat</a>
# </td></tr>
# <tr>
# <td colspan="5">South Korean communications satellite built on the <a href="/wiki/Spacebus" title="Spacebus">Spacebus-4000B2</a> platform. To be positioned at 116° East.<sup class="reference" id="cite_ref-444"><a href="#cite_note-444">[436]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">H2 2024<sup class="reference" id="cite_ref-nextSFupcoming_393-8"><a href="#cite_note-nextSFupcoming-393">[385]</a></sup><sup class="reference" id="cite_ref-SFPR9321_445-0"><a href="#cite_note-SFPR9321-445">[437]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a><sup class="reference" id="cite_ref-ussf36config_446-0"><a href="#cite_note-ussf36config-446">[438]</a></sup>
# </td>
# <td>TBA (FL)<sup class="reference" id="cite_ref-ussf36location_447-0"><a href="#cite_note-ussf36location-447">[439]</a></sup>
# </td>
# <td>USSF-36
# </td>
# <td class="skin-invert no table-no2" data-sort-value="" style="background: #DDF; color:black; vertical-align: middle; text-align: center;"><abbr title="To be announced">TBA</abbr>
# </td>
# <td><a href="/wiki/United_States_Space_Force" title="United States Space Force">USSF</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2021.<sup class="reference" id="cite_ref-defense.gov_448-0"><a href="#cite_note-defense.gov-448">[440]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">H2 2024<sup class="reference" id="cite_ref-O3b_Nov23_449-0"><a href="#cite_note-O3b_Nov23-449">[441]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td>TBA (FL)
# </td>
# <td><a href="/wiki/O3b_mPOWER" title="O3b mPOWER">O3b mPOWER</a> 7 &amp; 8
# </td>
# <td><a href="/wiki/Medium_Earth_orbit" title="Medium Earth orbit">MEO</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# </td></tr>
# <tr>
# <td colspan="5">In August 2020, SES expanded the O3b mPOWER contract with two additional launches, raising the number of satellites from 7 to 11 satellites at nearly 2 tons each.<sup class="reference" id="cite_ref-450"><a href="#cite_note-450">[442]</a></sup><sup class="reference" id="cite_ref-businesswire.com_451-0"><a href="#cite_note-businesswire.com-451">[443]</a></sup> In October 2023 the mission was delayed to the second half of 2024 due to electrical issues discovered in the first four satellites of the constellation.<sup class="reference" id="cite_ref-O3b_Nov23_449-1"><a href="#cite_note-O3b_Nov23-449">[441]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">H2 2024<sup class="reference" id="cite_ref-shephard14224_399-1"><a href="#cite_note-shephard14224-399">[391]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a> ♺<sup class="reference" id="cite_ref-worldviewlegion_341-3"><a href="#cite_note-worldviewlegion-341">[333]</a></sup><sup class="reference" id="cite_ref-WorldView-Legion_1,_...,_6_400-1"><a href="#cite_note-WorldView-Legion_1,_...,_6-400">[392]</a></sup>
# </td>
# <td>TBA (FL)<sup class="reference" id="cite_ref-nextSFupcoming_393-9"><a href="#cite_note-nextSFupcoming-393">[385]</a></sup>
# </td>
# <td><a href="/wiki/DigitalGlobe#WorldView_Legion" title="DigitalGlobe">WorldView Legion 5 &amp; 6</a> Mission 3 (2 sats)<sup class="reference" id="cite_ref-spacenews.com_401-1"><a href="#cite_note-spacenews.com-401">[393]</a></sup><sup class="reference" id="cite_ref-SN240423_402-1"><a href="#cite_note-SN240423-402">[394]</a></sup><sup class="reference" id="cite_ref-worldviewLegion10QSept22_403-1"><a href="#cite_note-worldviewLegion10QSept22-403">[395]</a></sup>
# </td>
# <td><a href="/wiki/Sun-synchronous_orbit" title="Sun-synchronous orbit">SSO</a>
# </td>
# <td><a href="/wiki/Maxar_Technologies" title="Maxar Technologies">Maxar Technologies</a>
# </td></tr>
# <tr>
# <td colspan="5"><a href="/wiki/Maxar_Technologies" title="Maxar Technologies">Maxar Technologies</a> built satellites.
# </td></tr>
# <tr>
# <td rowspan="2">H2 2024<sup class="reference" id="cite_ref-nextSFupcoming_393-10"><a href="#cite_note-nextSFupcoming-393">[385]</a></sup><sup class="reference" id="cite_ref-SFPR9321_445-1"><a href="#cite_note-SFPR9321-445">[437]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a><sup class="reference" id="cite_ref-ussf36config_446-1"><a href="#cite_note-ussf36config-446">[438]</a></sup>
# </td>
# <td>TBA (FL)
# </td>
# <td>NROL-69
# </td>
# <td class="skin-invert no table-no2" data-sort-value="" style="background: #DDF; color:black; vertical-align: middle; text-align: center;"><abbr title="To be announced">TBA</abbr>
# </td>
# <td><a href="/wiki/United_States_Space_Force" title="United States Space Force">USSF</a>
# </td></tr>
# <tr>
# <td colspan="5">Launch part of Phase 2 US Space Force contract awarded in 2021.<sup class="reference" id="cite_ref-defense.gov_448-1"><a href="#cite_note-defense.gov-448">[440]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">Late 2024<sup class="reference" id="cite_ref-452"><a href="#cite_note-452">[444]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td>TBA (FL)
# </td>
# <td><a href="/wiki/PT_Pasifik_Satelit_Nusantara#Nusantara_Lima" title="PT Pasifik Satelit Nusantara">Nusantara Lima</a><sup class="reference" id="cite_ref-453"><a href="#cite_note-453">[445]</a></sup>
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>?
# </td>
# <td><a href="/wiki/PT_Pasifik_Satelit_Nusantara" title="PT Pasifik Satelit Nusantara">PT Pasifik Satelit Nusantara</a>
# </td></tr>
# <tr>
# <td colspan="5">A hot backup system for <a href="/wiki/PT_Pasifik_Satelit_Nusantara#SATRIA-1" title="PT Pasifik Satelit Nusantara">SATRIA-1</a>.<sup class="reference" id="cite_ref-454"><a href="#cite_note-454">[446]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">2024<sup class="reference" id="cite_ref-nextSFupcoming_393-11"><a href="#cite_note-nextSFupcoming-393">[385]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a> ♺
# </td>
# <td>TBA (FL)
# </td>
# <td><a href="/wiki/Doge-1" title="Doge-1">DOGE-1</a> <span style="color:darkgreen"><abbr title="It is not yet clear whether this will fly as a primary payload, a secondary payload or on a dedicated rideshare mission">Possible rideshare</abbr></span>
# </td>
# <td><a href="/wiki/Trans-lunar_injection" title="Trans-lunar injection">TLI</a>
# </td>
# <td>Geometric Energy
# </td></tr>
# <tr>
# <td colspan="5">Originally expected to be a secondary rideshare payload on <a href="/wiki/IM-1" title="IM-1">IM-1</a> mission but the 40 kg was later postponed to a later date due to incomplete radio and launch requirements.&gt;<sup class="reference" id="cite_ref-455"><a href="#cite_note-455">[447]</a></sup><sup class="noprint Inline-Template noprint Template-Fact" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:No_original_research#Primary,_secondary_and_tertiary_sources" title="Wikipedia:No original research"><span title="This claim needs references to reliable secondary sources. (February 2024)">non-primary source needed</span></a></i>]</sup>
# </td></tr>
# <tr>
# <td rowspan="2">2024<sup class="reference" id="cite_ref-ispr25122_456-0"><a href="#cite_note-ispr25122-456">[448]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td>TBD
# </td>
# <td><a href="/wiki/Ispace_(Japanese_company)" title="Ispace (Japanese company)">ispace</a> 2nd lunar lander<sup class="reference" id="cite_ref-457"><a href="#cite_note-457">[449]</a></sup>
# </td>
# <td><a class="mw-redirect" href="/wiki/Trans_Lunar_Injection" title="Trans Lunar Injection">TLI</a>
# </td>
# <td><a href="/wiki/Ispace_(Japanese_company)" title="Ispace (Japanese company)">ispace</a>
# </td></tr>
# <tr>
# <td colspan="5">Second lunar lander built by Japanese company <a href="/wiki/Ispace_(Japanese_company)" title="Ispace (Japanese company)">ispace</a>.
# </td></tr>
# <tr>
# <td rowspan="2">2024<sup class="reference" id="cite_ref-458"><a href="#cite_note-458">[450]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td>TBA (FL)
# </td>
# <td><a href="/wiki/Thuraya#Satellites" title="Thuraya">Thuraya 4-NGS</a>
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>
# </td>
# <td><a href="/wiki/Thuraya" title="Thuraya">Thuraya</a>
# </td></tr>
# <tr>
# <td colspan="5">Planned replacement for Thuraya 2.<sup class="reference" id="cite_ref-459"><a href="#cite_note-459">[451]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">2024
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td>TBD
# </td>
# <td>Reentry demonstration capsule <span style="color:darkgreen"><abbr title="It is not yet clear whether this will fly as a primary payload, a secondary payload or on a dedicated rideshare mission">Possible rideshare</abbr></span>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/The_Exploration_Company" title="The Exploration Company">The Exploration Company</a>
# </td></tr>
# <tr>
# <td colspan="5">1600 kg 2.5 metre diameter reduced scale test of a reentry capsule, the full-scale version Nyx (4 metre diameter 8000 kg) is planned to deliver payloads to the ISS and return them back to Earth.<sup class="reference" id="cite_ref-460"><a href="#cite_note-460">[452]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">2024?
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">F9<span class="nowrap"> </span>B5</a>
# </td>
# <td>TBA (FL)
# </td>
# <td>USSF-31<sup class="reference" id="cite_ref-SSCA12_414-5"><a href="#cite_note-SSCA12-414">[406]</a></sup>
# </td>
# <td class="skin-invert no table-no2" data-sort-value="" style="background: #DDF; color:black; vertical-align: middle; text-align: center;"><abbr title="To be announced">TBA</abbr>
# </td>
# <td><a href="/wiki/United_States_Space_Force" title="United States Space Force">USSF</a>
# </td></tr>
# <tr>
# <td colspan="5">Classified mission, part of Phase 2 US Space Force contract awarded in 2022.
# </td></tr></tbody></table>

# %% [markdown]
# You should able to see the columns names embedded in the table header elements `<th>` as follows:

# %% [markdown]
# ```
# <tr>
# <th scope="col">Flight No.
# </th>
# <th scope="col">Date and<br/>time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>Booster</a> <sup class="reference" id="cite_ref-booster_11-0"><a href="#cite_note-booster-11">[b]</a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_12-0"><a href="#cite_note-Dragon-12">[c]</a></sup>
# </th>
# <th scope="col">Payload mass
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th>
# <th scope="col">Launch<br/>outcome
# </th>
# <th scope="col"><a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">Booster<br/>landing</a>
# </th></tr>
# ```

# %% [markdown]
# Next, we just need to iterate through the `<th>` elements and apply the provided `extract_column_from_header()` to extract column name one by one

# %%
column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names
temp = soup.find_all('th')
for x in range(len(temp)):
    try:
     name = extract_column_from_header(temp[x])
     if (name is not None and len(name) > 0):
        column_names.append(name) 
    except:
     pass

# %% [markdown]
# Check the extracted column names

# %%
print(column_names)
# Out:
# ['Flight No.', 'Date and time ( )', 'Launch site', 'Payload', 'Payload mass', 'Orbit', 'Customer', 'Launch outcome', 'FH 5', 'FH 6', 'FH 7', 'FH 8', 'FH 9', 'Date and time ( )', 'Launch site', 'Payload', 'Payload mass', 'Orbit', 'Customer', 'Launch outcome', 'FH 10', 'Date and time ( )', 'Launch site', 'Payload', 'Orbit', 'Customer', 'Date and time ( )', 'Launch site', 'Payload', 'Orbit', 'Customer', 'Date and time ( )', 'Launch site', 'Payload', 'Orbit', 'Customer', 'Demonstration', 'logistics', 'Crewed', 'Commercial satellites', 'Scientific satellites', 'Military satellites', 'Rideshares', 'Transporter', 'Bandwagon', 'Current', 'In development', 'Retired', 'Cancelled', 'Spacecraft', 'Cargo', 'Crewed', 'Test vehicles', 'Current', 'Retired', 'Unflown', 'Orbital', 'Atmospheric', 'Landing sites', 'Other facilities', 'Support', 'Contracts', 'R&D programs', 'Key people', 'Related', 'General', 'General', 'People', 'Vehicles', 'Launches by rocket type', 'Launches by spaceport', 'Agencies, companies and facilities', 'Other mission lists and timelines']

# %% [markdown]
# ## TASK 3: Create a data frame by parsing the launch HTML tables

# %% [markdown]
# We will create an empty dictionary with keys from the extracted column names in the previous task. Later, this dictionary will be converted into a Pandas dataframe

# %%
launch_dict= dict.fromkeys(column_names)

# Remove an irrelvant column
#del launch_dict['Date and time ( )']

# Let's initial the launch_dict with each value to be an empty list
launch_dict['Flight No.'] = []
launch_dict['Launch site'] = []
launch_dict['Payload'] = []
launch_dict['Payload mass'] = []
launch_dict['Orbit'] = []
launch_dict['Customer'] = []
launch_dict['Launch outcome'] = []
# Added some new columns
launch_dict['Version Booster']=[]
launch_dict['Booster landing']=[]
launch_dict['Date']=[]
launch_dict['Time']=[]

# %% [markdown]
# Next, we just need to fill up the `launch_dict` with launch records extracted from table rows.

# %% [markdown]
# Usually, HTML tables in Wiki pages are likely to contain unexpected annotations and other types of noises, such as reference links `B0004.1[8]`, missing values `N/A [e]`, inconsistent formatting, etc.

# %% [markdown]
# To simplify the parsing process, we have provided an incomplete code snippet below to help you to fill up the `launch_dict`. Please complete the following code snippet with TODOs or you can choose to write your own logic to parse all launch tables:

# %%
extracted_row = 0
launch_dict = []

# Extract each table
for table_number, table in enumerate(soup.find_all('table', "wikitable plainrowheaders collapsible")):
    # Get table row 
    for rows in table.find_all("tr"):
        # Check to see if first table heading is a number corresponding to launch number 
        if rows.th and rows.th.string:
            flight_number = rows.th.string.strip()
            flag = flight_number.isdigit()
        else:
            flag = False
        
        # Get table elements
        row = rows.find_all('td')
        
        # If it is a number, save cells in a dictionary 
        if flag:
            extracted_row += 1
            launch_data = {}
            
            # Flight Number value
            launch_data['Flight No.'] = flight_number
            
            # Date and Time values
            datatimelist = date_time(row[0])
            launch_data['Date'] = datatimelist[0].strip(',')
            launch_data['Time'] = datatimelist[1]
            
            # Booster version
            bv = booster_version(row[1])
            if not bv:
                bv = row[1].a.string if row[1].a else None
            launch_data['Version Booster'] = bv
            
            # Launch Site
            launch_data['Launch Site'] = row[2].a.string if row[2].a else None
            
            # Payload
            launch_data['Payload'] = row[3].a.string if row[3].a else None
            
            # Payload Mass
            payload_mass = get_mass(row[4])
            launch_data['Payload mass'] = payload_mass
            
            # Orbit
            launch_data['Orbit'] = row[5].a.string if row[5].a else None
            
            # Customer
            launch_data['Customer'] = row[6].a.string if row[6].a else None
            
            # Launch outcome
            launch_data['Launch outcome'] = list(row[7].strings)[0] if row[7] else None
            
            # Booster landing
            launch_data['Booster landing'] = landing_status(row[8]) if row[8] else None
            
            # Append the launch_data dictionary to the list
            launch_dict.append(launch_data)

# Print the extracted data
for launch in launch_dict:
    print(launch)
# Out:
# {'Flight No.': '195', 'Date': '3 January 2023', 'Time': '14:56', 'Version Booster': 'F9B5\xa0', 'Launch Site': 'Cape Canaveral', 'Payload': 'Transporter 6', 'Payload mass': 'U', 'Orbit': 'SSO', 'Customer': None, 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '196', 'Date': '10 January 2023', 'Time': '04:50', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'OneWeb', 'Payload mass': '6,000 kg', 'Orbit': 'Polar', 'Customer': 'OneWeb', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '197', 'Date': '18 January 2023', 'Time': '12:24', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'USA-343', 'Payload mass': '4,352 kg', 'Orbit': 'MEO', 'Customer': 'USSF', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '198', 'Date': '19 January 2023', 'Time': '15:43', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 2–4', 'Payload mass': '15,000 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '199', 'Date': '26 January 2023', 'Time': '09:32', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 5-2', 'Payload mass': '~17,400 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '200', 'Date': '31 January 2023', 'Time': '16:15', 'Version Booster': 'F9B5\xa0', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 2–6', 'Payload mass': '~15,200 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '201', 'Date': '2 February 2023', 'Time': '07:58', 'Version Booster': 'F9B5', 'Launch Site': 'Kennedy', 'Payload': 'Starlink Group 5-3', 'Payload mass': '16,500 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '202', 'Date': '7 February 2023', 'Time': '01:32', 'Version Booster': 'F9B5\xa0', 'Launch Site': 'Cape Canaveral', 'Payload': 'Amazonas Nexus', 'Payload mass': '4,146 kg', 'Orbit': 'GTO', 'Customer': 'Hispasat', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '203', 'Date': '12 February 2023', 'Time': '05:10', 'Version Booster': 'F9B5\xa0', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 5-4', 'Payload mass': '17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '204', 'Date': '17 February 2023', 'Time': '19:12', 'Version Booster': 'F9B5\xa0', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 2–5', 'Payload mass': '15,900 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '205', 'Date': '18 February 2023', 'Time': '03:59', 'Version Booster': 'F9B5\xa0', 'Launch Site': 'Cape Canaveral', 'Payload': 'Inmarsat-6 F2', 'Payload mass': '5,470 kg', 'Orbit': 'GTO', 'Customer': 'Inmarsat', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '206', 'Date': '27 February 2023', 'Time': '23:13', 'Version Booster': 'F9B5\xa0', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6-1', 'Payload mass': '~15,300 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '207', 'Date': '2 March 2023', 'Time': '05:34', 'Version Booster': 'F9B5', 'Launch Site': 'Kennedy', 'Payload': 'Crew-6', 'Payload mass': '~13,000 kg', 'Orbit': 'LEO', 'Customer': 'NASA', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '208', 'Date': '3 March 2023', 'Time': '18:38', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 2–7', 'Payload mass': '15,900 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '209', 'Date': '9 March 2023', 'Time': '19:13', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'OneWeb #17', 'Payload mass': '6,000 kg', 'Orbit': 'LEO', 'Customer': 'OneWeb', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '210', 'Date': '15 March 2023', 'Time': '00:30', 'Version Booster': 'F9B5\xa0', 'Launch Site': 'Kennedy', 'Payload': 'SpaceX CRS-27', 'Payload mass': '2,852 kg', 'Orbit': 'LEO', 'Customer': 'NASA', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '211', 'Date': '17 March 2023', 'Time': '19:26', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 2–8', 'Payload mass': '~16,200 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '212', 'Date': '17 March 2023', 'Time': '23:38', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'SES-18 and SES-19', 'Payload mass': '~7,000 kg', 'Orbit': 'GTO', 'Customer': 'SES', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '213', 'Date': '24 March 2023', 'Time': '15:43', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 5-5', 'Payload mass': '~17,400 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '214', 'Date': '29 March 2023', 'Time': '20:01', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 5–10', 'Payload mass': '~17,400 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '215', 'Date': '2 April 2023', 'Time': '14:29', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Transport and Tracking Layer (Tranche 0A)', 'Payload mass': 'U', 'Orbit': 'LEO', 'Customer': 'SDA', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '216', 'Date': '7 April 2023', 'Time': '04:30', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Intelsat 40e', 'Payload mass': '~5,588 kg', 'Orbit': 'GTO', 'Customer': 'Intelsat', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '217', 'Date': '15 April 2023', 'Time': '06:47', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Transporter-7', 'Payload mass': 'U', 'Orbit': 'SSO', 'Customer': None, 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '218', 'Date': '19 April 2023', 'Time': '14:31', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6-2', 'Payload mass': '~15,300 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '219', 'Date': '27 April 2023', 'Time': '13:40', 'Version Booster': 'F9B5B1061.13', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 3–5', 'Payload mass': '~14,100 kg', 'Orbit': 'SSO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '220', 'Date': '28 April 2023', 'Time': '22:12', 'Version Booster': 'F9B5\xa0', 'Launch Site': 'Cape Canaveral', 'Payload': 'O3b mPOWER', 'Payload mass': '~4,100 kg', 'Orbit': 'MEO', 'Customer': 'SES', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '221', 'Date': '4 May 2023', 'Time': '07:31', 'Version Booster': 'F9B5\xa0', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 5–6', 'Payload mass': '~17,400 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '222', 'Date': '10 May 2023', 'Time': '20:09', 'Version Booster': 'F9B5\xa0', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 2–9', 'Payload mass': '15,900 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '223', 'Date': '14 May 2023', 'Time': '05:03', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 5–9', 'Payload mass': '~17,400 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '224', 'Date': '19 May 2023', 'Time': '06:19', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6-3', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '225', 'Date': '20 May 2023', 'Time': '13:16', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Iridium-NEXT', 'Payload mass': '~6,600 kg', 'Orbit': 'Polar', 'Customer': 'Iridium', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '226', 'Date': '21 May 2023', 'Time': '21:37', 'Version Booster': 'F9B5', 'Launch Site': 'Kennedy', 'Payload': 'Ax-2', 'Payload mass': '~13,000 kg', 'Orbit': 'LEO', 'Customer': 'Axiom Space', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '227', 'Date': '27 May 2023', 'Time': '04:30', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'ArabSat 7B', 'Payload mass': '~4,500 kg', 'Orbit': 'GTO', 'Customer': 'Arabsat', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '228', 'Date': '31 May 2023', 'Time': '06:02', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 2–10', 'Payload mass': '~16,400 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '229', 'Date': '4 June 2023', 'Time': '12:20', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6-4', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '230', 'Date': '5 June 2023', 'Time': '15:47', 'Version Booster': 'F9B5\xa0', 'Launch Site': 'Kennedy', 'Payload': 'SpaceX CRS-28', 'Payload mass': '~9,525 kg', 'Orbit': 'LEO', 'Customer': 'NASA', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '231', 'Date': '12 June 2023', 'Time': '07:10', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 5–11', 'Payload mass': '~16,400 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '232', 'Date': '12 June 2023', 'Time': '21:35', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Transporter-8', 'Payload mass': 'U', 'Orbit': 'SSO', 'Customer': None, 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '233', 'Date': '18 June 2023', 'Time': '22:21', 'Version Booster': 'F9B5\xa0', 'Launch Site': 'Cape Canaveral', 'Payload': 'SATRIA', 'Payload mass': '~4,580 kg', 'Orbit': 'GTO', 'Customer': 'PT Pasifik Satelit Nusantara', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '234', 'Date': '22 June 2023', 'Time': '07:19', 'Version Booster': 'F9B5\xa0', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 5–7', 'Payload mass': '~14,500 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '235', 'Date': '23 June 2023', 'Time': '15:35', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 5–12', 'Payload mass': '~17,400 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '236', 'Date': '1 July 2023', 'Time': '15:12', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Euclid', 'Payload mass': '~2,160 kg', 'Orbit': None, 'Customer': 'ESA', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '237', 'Date': '7 July 2023', 'Time': '19:29', 'Version Booster': 'F9B5\xa0', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 5–13', 'Payload mass': '~14,900 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '238', 'Date': '10 July 2023', 'Time': '03:58', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6-5', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '239', 'Date': '16 July 2023', 'Time': '03:50', 'Version Booster': 'F9B5\xa0', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 5–15', 'Payload mass': '~16,700 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '240', 'Date': '20 July 2023', 'Time': '04:09', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 6–15', 'Payload mass': '~12,000 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '241', 'Date': '24 July 2023', 'Time': '00:50', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6-6', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '242', 'Date': '28 July 2023', 'Time': '04:01', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–7', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '243', 'Date': '3 August 2023', 'Time': '05:00', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Galaxy 37', 'Payload mass': '~5,063 kg', 'Orbit': 'GTO', 'Customer': 'Intelsat', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '244', 'Date': '7 August 2023', 'Time': '02:41', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–8', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '245', 'Date': '8 August 2023', 'Time': '03:57', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 6–20', 'Payload mass': '~12,000 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '246', 'Date': '11 August 2023', 'Time': '05:17', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–9', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '247', 'Date': '17 August 2023', 'Time': '03:36', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–10', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '248', 'Date': '22 August 2023', 'Time': '09:37', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 7-1', 'Payload mass': '~15,300 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '249', 'Date': '26 August 2023', 'Time': '07:27', 'Version Booster': 'F9B5', 'Launch Site': 'Kennedy', 'Payload': 'Crew-7', 'Payload mass': '~13,000 kg', 'Orbit': 'LEO', 'Customer': 'NASA', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '250', 'Date': '27 August 2023', 'Time': '01:05', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–11', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '251', 'Date': '1 September 2023', 'Time': '02:21', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–13', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '252', 'Date': '2 September 2023', 'Time': '[187]', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Transport and Tracking Layer (Tranche 0B)', 'Payload mass': 'U', 'Orbit': 'LEO', 'Customer': 'SDA', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '253', 'Date': '4 September 2023', 'Time': '02:47', 'Version Booster': 'F9B5', 'Launch Site': 'Kennedy', 'Payload': 'Starlink Group 6–12', 'Payload mass': '~15,300 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '254', 'Date': '9 September 2023', 'Time': '03:12', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–14', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '255', 'Date': '12 September 2023', 'Time': '06:57', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 7-2', 'Payload mass': '~15,300 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '256', 'Date': '16 September 2023', 'Time': '03:38', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–16', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '257', 'Date': '20 September 2023', 'Time': '03:38', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–17', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '258', 'Date': '24 September 2023', 'Time': '03:38', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–18', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '259', 'Date': '25 September 2023', 'Time': '08:48', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 7-3', 'Payload mass': '~15,300 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '260', 'Date': '30 September 2023', 'Time': '02:00', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–19', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '261', 'Date': '5 October 2023', 'Time': '05:36', 'Version Booster': 'F9B5\xa0', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–21', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '262', 'Date': '9 October 2023', 'Time': '07:23', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 7-4', 'Payload mass': '~15,300 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '263', 'Date': '13 October 2023', 'Time': '23:01', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–22', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '264', 'Date': '18 October 2023', 'Time': '00:39', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–23', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '265', 'Date': '21 October 2023', 'Time': '08:23', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 7-5', 'Payload mass': '~15,300 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '266', 'Date': '22 October 2023', 'Time': '02:17', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–24', 'Payload mass': '~16,800 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '267', 'Date': '29 October 2023', 'Time': '09:00', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 7-6', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '268', 'Date': '30 October 2023', 'Time': '23:20', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–25', 'Payload mass': '~16,800 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '269', 'Date': '4 November 2023', 'Time': '00:37', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–26', 'Payload mass': '~16,800 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '270', 'Date': '8 November 2023', 'Time': '05:05', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–27', 'Payload mass': '~16,800 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '271', 'Date': '10 November 2023', 'Time': '01:28', 'Version Booster': 'F9B5', 'Launch Site': 'Kennedy', 'Payload': 'SpaceX CRS-29', 'Payload mass': '~9,525 kg', 'Orbit': 'LEO', 'Customer': 'NASA', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '272', 'Date': '11 November 2023', 'Time': '18:49', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Transporter-9', 'Payload mass': 'U', 'Orbit': 'SSO', 'Customer': None, 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '273', 'Date': '12 November 2023', 'Time': '21:08', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'O3b mPOWER', 'Payload mass': '~4,100 kg', 'Orbit': 'MEO', 'Customer': 'SES', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '274', 'Date': '18 November 2023', 'Time': '05:05', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–28', 'Payload mass': '~16,800 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '275', 'Date': '20 November 2023', 'Time': '10:30', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 7-7', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '276', 'Date': '22 November 2023', 'Time': '07:47', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–29', 'Payload mass': '~16,800 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '277', 'Date': '28 November 2023', 'Time': '04:20', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–30', 'Payload mass': '~16,800 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '278', 'Date': '1 December 2023', 'Time': '18:19', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': '[227]', 'Payload mass': '~800 kg', 'Orbit': 'SSO', 'Customer': 'Republic of Korea Armed Forces', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '279', 'Date': '3 December 2023', 'Time': '04:00', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–31', 'Payload mass': '~16,800 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '280', 'Date': '7 December 2023', 'Time': '05:07', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–33', 'Payload mass': '~16,800 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '281', 'Date': '8 December 2023', 'Time': '08:03', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 7–8', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '282', 'Date': '19 December 2023', 'Time': '04:01', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–34', 'Payload mass': '~16,800 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '283', 'Date': '23 December 2023', 'Time': '05:33', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–32', 'Payload mass': '~16,800 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Partial failure'}
# {'Flight No.': '284', 'Date': '24 December 2023', 'Time': '13:11', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'SARah', 'Payload mass': '~3,600 kg', 'Orbit': 'SSO', 'Customer': 'German Intelligence Service', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '285', 'Date': '29 December 2023', 'Time': '04:01', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–36', 'Payload mass': '~16,800 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '286', 'Date': '3 January 2024', 'Time': '03:44', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 7–9', 'Payload mass': '~16,800 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '287', 'Date': '3 January 2024', 'Time': '23:04', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Ovzon-3', 'Payload mass': '1,800 kg', 'Orbit': 'GTO', 'Customer': 'Ovzon', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '288', 'Date': '7 January 2024', 'Time': '22:35', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–35', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '289', 'Date': '14 January 2024', 'Time': '08:59', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 7–10', 'Payload mass': '~16,700 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '290', 'Date': '15 January 2024', 'Time': '01:52', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–37', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '291', 'Date': '18 January 2024', 'Time': '21:49', 'Version Booster': 'F9B5', 'Launch Site': 'Kennedy', 'Payload': 'Ax-3', 'Payload mass': '~13,000 kg', 'Orbit': 'LEO', 'Customer': 'Axiom Space', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '292', 'Date': '24 January 2024', 'Time': '00:35', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 7–11', 'Payload mass': '~16,700 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '293', 'Date': '29 January 2024', 'Time': '01:10', 'Version Booster': 'F9B5', 'Launch Site': 'Kennedy', 'Payload': 'Starlink Group 6–38', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '294', 'Date': '29 January 2024', 'Time': '05:57', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 7–12', 'Payload mass': '~16,700 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '295', 'Date': '30 January 2024', 'Time': '17:07', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'NG-20', 'Payload mass': '3,726 kg', 'Orbit': 'LEO', 'Customer': 'Northrop Grumman', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '296', 'Date': '8 February 2024', 'Time': '06:33', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'PACE', 'Payload mass': '1,694 kg', 'Orbit': 'SSO', 'Customer': 'NASA', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '297', 'Date': '10 February 2024', 'Time': '00:34', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 7–13', 'Payload mass': '~16,700 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '298', 'Date': '14 February 2024', 'Time': '22:30', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'SDA', 'Payload mass': 'U', 'Orbit': 'LEO', 'Customer': 'USSF', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '299', 'Date': '15 February 2024', 'Time': '06:05', 'Version Booster': 'F9B5', 'Launch Site': 'Kennedy', 'Payload': 'IM-1', 'Payload mass': '1,931 kg', 'Orbit': 'TLI', 'Customer': 'NASA', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '300', 'Date': '15 February 2024', 'Time': '21:34', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 7–14', 'Payload mass': '~16,700 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '301', 'Date': '20 February 2024', 'Time': '20:11', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Merah Putih 2 / Telkomsat HTS 113BT', 'Payload mass': '4,000 kg', 'Orbit': 'GTO', 'Customer': 'Telkom Indonesia', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '302', 'Date': '23 February 2024', 'Time': '04:11', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 7–15', 'Payload mass': '~16,700 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '303', 'Date': '25 February 2024', 'Time': '22:06', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–39', 'Payload mass': '~17,500 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '304', 'Date': '29 February 2024', 'Time': '15:30', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–40', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '305', 'Date': '4 March 2024', 'Time': '03:53', 'Version Booster': 'F9B5', 'Launch Site': 'Kennedy', 'Payload': 'Crew-8', 'Payload mass': '~13,000 kg', 'Orbit': 'LEO', 'Customer': 'NASA', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '306', 'Date': '4 March 2024', 'Time': '22:05', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Transporter-10', 'Payload mass': 'U', 'Orbit': 'SSO', 'Customer': None, 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '307', 'Date': '4 March 2024', 'Time': '23:56', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–41', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '308', 'Date': '10 March 2024', 'Time': '23:05', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–43', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '309', 'Date': '11 March 2024', 'Time': '04:09', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 7–17', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '310', 'Date': '16 March 2024', 'Time': '00:21', 'Version Booster': 'F9B5', 'Launch Site': 'Kennedy', 'Payload': 'Starlink Group 6–44', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '311', 'Date': '19 March 2024', 'Time': '02:28', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 7–16', 'Payload mass': '~16,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '312', 'Date': '21 March 2024', 'Time': '20:55', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'SpaceX CRS-30', 'Payload mass': '2,721 kg', 'Orbit': 'LEO', 'Customer': 'NASA', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '313', 'Date': '24 March 2024', 'Time': '03:09', 'Version Booster': 'F9B5', 'Launch Site': 'Kennedy', 'Payload': 'Starlink Group 6–42', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '314', 'Date': '25 March 2024', 'Time': '23:42', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–46', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '315', 'Date': '30 March 2024', 'Time': '21:52', 'Version Booster': 'F9B5', 'Launch Site': 'Kennedy', 'Payload': None, 'Payload mass': '5,000 kg', 'Orbit': 'GTO', 'Customer': 'Eutelsat', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '316', 'Date': '31 March 2024', 'Time': '01:30', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–45', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '317', 'Date': '2 April 2024', 'Time': '02:30', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 7–18', 'Payload mass': '~16,700 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '318', 'Date': '5 April 2024', 'Time': '09:12', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–47', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '319', 'Date': '7 April 2024', 'Time': '02:25', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 8-1', 'Payload mass': '~16,800 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '320', 'Date': '7 April 2024', 'Time': '23:16', 'Version Booster': 'F9B5', 'Launch Site': 'Kennedy', 'Payload': 'Bandwagon-1', 'Payload mass': 'U', 'Orbit': 'LEO', 'Customer': None, 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '321', 'Date': '10 April 2024', 'Time': '05:40', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–48', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '322', 'Date': '11 April 2024', 'Time': '14:25', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'WSF-M 1', 'Payload mass': '1,200 kg', 'Orbit': 'SSO', 'Customer': 'USSF', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '323', 'Date': '13 April 2024', 'Time': '01:40', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–49', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '324', 'Date': '17 April 2024', 'Time': '21:26', 'Version Booster': 'F9B5', 'Launch Site': 'Kennedy', 'Payload': 'Starlink Group 6–51', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '325', 'Date': '18 April 2024', 'Time': '22:40', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–52', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '326', 'Date': '23 April 2024', 'Time': '22:17', 'Version Booster': 'F9B5\xa0', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–53', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '327', 'Date': '28 April 2024', 'Time': '00:34', 'Version Booster': 'F9B5', 'Launch Site': 'Kennedy', 'Payload': 'Galileo', 'Payload mass': '1,600 kg', 'Orbit': 'MEO', 'Customer': 'ESA', 'Launch outcome': 'Success\n', 'Booster landing': 'No attempt\n'}
# {'Flight No.': '328', 'Date': '28 April 2024', 'Time': '22:08', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–54', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '329', 'Date': '2 May 2024', 'Time': '18:36', 'Version Booster': 'F9B5\xa0', 'Launch Site': 'Vandenberg', 'Payload': 'WorldView Legion 1 & 2', 'Payload mass': '1,500 kg', 'Orbit': 'SSO', 'Customer': 'Maxar Technologies', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '330', 'Date': '3 May 2024', 'Time': '02:37', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–55', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '331', 'Date': '6 May 2024', 'Time': '18:14', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–57', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '332', 'Date': '8 May 2024', 'Time': '18:42', 'Version Booster': 'F9B5', 'Launch Site': 'Kennedy', 'Payload': 'Starlink Group 6–56', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '333', 'Date': '10 May 2024', 'Time': '04:30', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 8-2', 'Payload mass': '~16,300 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '334', 'Date': '13 May 2024', 'Time': '00:53', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–58', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '335', 'Date': '14 May 2024', 'Time': '18:39', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 8-7', 'Payload mass': '~16,300 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '336', 'Date': '18 May 2024', 'Time': '00:32', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–59', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '337', 'Date': '22 May 2024', 'Time': '08:00', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starshield', 'Payload mass': 'U', 'Orbit': 'LEO', 'Customer': 'Northrop Grumman', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '338', 'Date': '23 May 2024', 'Time': '02:35', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–62', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '339', 'Date': '24 May 2024', 'Time': '02:45', 'Version Booster': 'F9B5', 'Launch Site': 'Kennedy', 'Payload': 'Starlink Group 6–63', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '340', 'Date': '28 May 2024', 'Time': '14:24', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–60', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '341', 'Date': '28 May 2024', 'Time': '22:20', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'EarthCARE', 'Payload mass': '2,350 kg', 'Orbit': 'SSO', 'Customer': 'ESA', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '342', 'Date': '1 June 2024', 'Time': '02:37', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 6–64', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '343', 'Date': '5 June 2024', 'Time': '02:16', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 8–5', 'Payload mass': '~16,300 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '344', 'Date': '8 June 2024', 'Time': '01:56', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 10–1', 'Payload mass': '~16,700 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '345', 'Date': '8 June 2024', 'Time': '12:58', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 8–8', 'Payload mass': '~16,300 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '346', 'Date': '19 June 2024', 'Time': '03:40', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 9–1', 'Payload mass': '~16,300 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '347', 'Date': '20 June 2024', 'Time': '21:35', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Astra 1P/SES-24', 'Payload mass': '5,000 kg', 'Orbit': 'GTO', 'Customer': 'SES', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '348', 'Date': '23 June 2024', 'Time': '17:15', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 10–2', 'Payload mass': '~16,700 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '349', 'Date': '24 June 2024', 'Time': '03:47', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 9–2', 'Payload mass': '~16,300 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '350', 'Date': '27 June 2024', 'Time': '11:14', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 10–3', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '351', 'Date': '29 June 2024', 'Time': '03:14', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starshield', 'Payload mass': 'U', 'Orbit': 'LEO', 'Customer': 'NRO', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '352', 'Date': '3 July 2024', 'Time': '08:55', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 8–9', 'Payload mass': '~16,300 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '353', 'Date': '8 July 2024', 'Time': '23:30', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Türksat 6A', 'Payload mass': '4,250 kg', 'Orbit': 'GTO', 'Customer': 'Türksat', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '354', 'Date': '12 July 2024', 'Time': '02:35', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 9–3', 'Payload mass': '~16,300 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Failure\n', 'Booster landing': 'Success'}
# {'Flight No.': '355', 'Date': '27 July 2024', 'Time': '05:45', 'Version Booster': 'F9B5', 'Launch Site': 'Kennedy', 'Payload': 'Starlink Group 10–9', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '356', 'Date': '28 July 2024', 'Time': '05:09', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'Starlink Group 10–4', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '357', 'Date': '28 July 2024', 'Time': '09:22', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 9–4', 'Payload mass': '~16,500 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '358', 'Date': '2 August 2024', 'Time': '05:01', 'Version Booster': 'F9B5', 'Launch Site': 'Kennedy', 'Payload': 'Starlink Group 10–6', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '359', 'Date': '4 August 2024', 'Time': '07:24', 'Version Booster': 'F9B5', 'Launch Site': 'Vandenberg', 'Payload': 'Starlink Group 11–1', 'Payload mass': '~17,100 kg', 'Orbit': 'LEO', 'Customer': 'SpaceX', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}
# {'Flight No.': '360', 'Date': '4 August 2024 15:02', 'Time': '[380]', 'Version Booster': 'F9B5', 'Launch Site': 'Cape Canaveral', 'Payload': 'CRS NG-21', 'Payload mass': '3,857 kg', 'Orbit': 'LEO', 'Customer': 'Northrop Grumman', 'Launch outcome': 'Success\n', 'Booster landing': 'Success'}

# %% [markdown]
# After you have fill in the parsed launch record values into `launch_dict`, you can create a dataframe from it.

# %%
df = pd.DataFrame(launch_dict)
df.head()
# Out:
#   Flight No.             Date   Time Version Booster     Launch Site  \
# 0        195   3 January 2023  14:56           F9B5   Cape Canaveral
# 1        196  10 January 2023  04:50            F9B5  Cape Canaveral
# 2        197  18 January 2023  12:24            F9B5  Cape Canaveral
# 3        198  19 January 2023  15:43            F9B5      Vandenberg
# 4        199  26 January 2023  09:32            F9B5  Cape Canaveral
#
#               Payload Payload mass  Orbit Customer Launch outcome  \
# 0       Transporter 6            U    SSO     None      Success\n
# 1              OneWeb     6,000 kg  Polar   OneWeb      Success\n
# 2             USA-343     4,352 kg    MEO     USSF      Success\n
# 3  Starlink Group 2–4    15,000 kg    LEO   SpaceX      Success\n
# 4  Starlink Group 5-2   ~17,400 kg    LEO   SpaceX      Success\n
#
#   Booster landing
# 0         Success
# 1         Success
# 2         Success
# 3         Success
# 4         Success

# %%
df.to_csv('spacex_web_scraped.csv', index=False)

# %% [markdown]
# We can now export it to a <b>CSV</b> for the next section, but to make the answers consistent and in case you have difficulties finishing this lab.
#
# Following labs will be using a provided dataset to make each lab independent.

# %% [markdown]
# <code>df.to_csv('spacex_web_scraped.csv', index=False)</code>

# %% [markdown]
# ## Authors

# %% [markdown]
# <a href="https://www.linkedin.com/in/yan-luo-96288783/">Yan Luo</a>

# %% [markdown]
# <a href="https://www.linkedin.com/in/nayefaboutayoun/">Nayef Abou Tayoun</a>

# %% [markdown]
# <!--
# ## Change Log
# -->

# %% [markdown]
# <!--
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description      |
# | ----------------- | ------- | ---------- | ----------------------- |
# | 2021-06-09        | 1.0     | Yan Luo    | Tasks updates           |
# | 2020-11-10        | 1.0     | Nayef      | Created the initial version |
# -->

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
